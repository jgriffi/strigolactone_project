# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## Hepatocellular Carcinoma

# %% [markdown]
# ### Target search for Hepatocellular Carcinoma

# %% [markdown]
# **See articles:**
# - Synthetic strigolactone analogues reveal anti-cancer activities on hepatocellular carcinoma cells

# %%
target = new_client.target
target_query = target.search('HepG2')
targets = pd.DataFrame(target_query)
targets
# Out:
#                                     cross_references      organism  \
# 0                                                 []  Homo sapiens
# 1                                                 []  Homo sapiens
# 2                                                 []  Homo sapiens
# 3  [{'xref_id': 'P11166', 'xref_name': None, 'xre...  Homo sapiens
#
#              pref_name  score  species_group_flag target_chembl_id  \
# 0                HepG2   18.0               False        CHEMBL395
# 1         HepG2 2.2.15   16.0               False    CHEMBL4296438
# 2           HepG2-CD81   16.0               False    CHEMBL4543887
# 3  Glucose transporter   14.0               False       CHEMBL2535
#
#                                    target_components     target_type  tax_id
# 0                                                 []       CELL-LINE    9606
# 1                                                 []       CELL-LINE    9606
# 2                                                 []       CELL-LINE    9606
# 3  [{'accession': 'P11166', 'component_descriptio...  SINGLE PROTEIN    9606

# %% [markdown]
#  ### Select and retrieve bioactivity data for _HepG2_ (1st entry)

# %% [markdown]
# We will assign the 1st entry (which corresponds to the target, *HepG2*) to the ***selected_target*** variable

# %%
row = ((targets["pref_name"] == 'HepG2')
       & (targets['organism'] == 'Homo sapiens')
       & (targets['target_type'] == 'CELL-LINE'))

# %%
protein_target = targets.loc[row]
protein_target
# Out:
#   cross_references      organism pref_name  score  species_group_flag  \
# 0               []  Homo sapiens     HepG2   18.0               False
#
#   target_chembl_id target_components target_type  tax_id
# 0        CHEMBL395                []   CELL-LINE    9606

# %%
activity = new_client.activity

# %%
data = []
for chembl_id in protein_target['target_chembl_id']:
    print(chembl_id)
    res = activity.filter(target_chembl_id=chembl_id).filter(standard_type="IC50")
    data.append(pd.DataFrame(res))
# Out:
# CHEMBL395

# %%
target_HepG2 = pd.concat(data, axis=0)
target_HepG2
# Out:
#       activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                 None        38273                  []    CHEMBL881719
# 1                 None        44218                  []    CHEMBL881719
# 2                 None        47846                  []    CHEMBL824182
# 3                 None        74264                  []    CHEMBL695846
# 4                 None        78722                  []    CHEMBL695847
# ...                ...          ...                 ...             ...
# 20477             None     20712344                  []   CHEMBL4629308
# 20478             None     20712348                  []   CHEMBL4629308
# 20479             None     20712352                  []   CHEMBL4629308
# 20480             None     20713305                  []   CHEMBL4629707
# 20481             None     20719209                  []   CHEMBL4509238
#
#                                        assay_description assay_type  \
# 0      The compound was tested for inhibition of chol...          F
# 1      The compound was tested for inhibition of chol...          F
# 2      The compound was tested for inhibition of chol...          F
# 3      Compound was tested in vitro for growth inhibi...          F
# 4      Compound was tested in vitro for growth inhibi...          F
# ...                                                  ...        ...
# 20477  Cytotoxicity against human HepG2 cells assesse...          F
# 20478  Cytotoxicity against human HepG2 cells assesse...          F
# 20479  Cytotoxicity against human HepG2 cells assesse...          F
# 20480  Cytotoxicity against human HepG2 cells after 4...          F
# 20481  Liver HepG2 cell line MDS Pharma Services Prol...          F
#
#       assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0                        None                   None  BAO_0000190
# 1                        None                   None  BAO_0000190
# 2                        None                   None  BAO_0000190
# 3                        None                   None  BAO_0000190
# 4                        None                   None  BAO_0000190
# ...                       ...                    ...          ...
# 20477                    None                   None  BAO_0000190
# 20478                    None                   None  BAO_0000190
# 20479                    None                   None  BAO_0000190
# 20480                    None                   None  BAO_0000190
# 20481                    None                   None  BAO_0000190
#
#         bao_format  ... target_organism target_pref_name target_tax_id  \
# 0      BAO_0000219  ...    Homo sapiens            HepG2          9606
# 1      BAO_0000219  ...    Homo sapiens            HepG2          9606
# 2      BAO_0000219  ...    Homo sapiens            HepG2          9606
# 3      BAO_0000219  ...    Homo sapiens            HepG2          9606
# 4      BAO_0000219  ...    Homo sapiens            HepG2          9606
# ...            ...  ...             ...              ...           ...
# 20477  BAO_0000219  ...    Homo sapiens            HepG2          9606
# 20478  BAO_0000219  ...    Homo sapiens            HepG2          9606
# 20479  BAO_0000219  ...    Homo sapiens            HepG2          9606
# 20480  BAO_0000219  ...    Homo sapiens            HepG2          9606
# 20481  BAO_0000219  ...    Homo sapiens            HepG2          9606
#
#       text_value  toid  type    units    uo_units upper_value  value
# 0           None  None  IC50       uM  UO_0000065        None    0.1
# 1           None  None  IC50       uM  UO_0000065        None    0.1
# 2           None  None  IC50       uM  UO_0000065        None    1.0
# 3           None  None  IC50  ug ml-1  UO_0000274        None   10.0
# 4           None  None  IC50  ug ml-1  UO_0000274        None   10.0
# ...          ...   ...   ...      ...         ...         ...    ...
# 20477       None  None  IC50       uM  UO_0000065        None   50.0
# 20478       None  None  IC50       uM  UO_0000065        None   50.0
# 20479       None  None  IC50       uM  UO_0000065        None   50.0
# 20480       None  None  IC50       uM  UO_0000065        None  100.0
# 20481       None  None  IC50       µM        None        None    3.1
#
# [20482 rows x 45 columns]

# %%
#Save to csv

#target_HepG2.to_csv('./data/strigolactone_target_HepG2.csv', index=False)
