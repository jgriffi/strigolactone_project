# %% [markdown]
# ## Descriptor Calculation

# %% [markdown]
# We will be preparing the descriptors using the **`tidy_target_HepG2_3classes`** file.

# %% [markdown]
# The molecular fingerprints were calculated using [PaDEL](https://onlinelibrary.wiley.com/doi/full/10.1002/jcc.21707) after following a tutorial by [Chanin Nantasenamat](https://github.com/dataprofessor).

# %%
import pandas as pd

# %% [markdown]
# ## Prepare descriptors

# %%
tidy_target_HepG2_3classes = pd.read_csv('./data/tidy_target_HepG2_3classes.csv')

# %%
tidy_target_HepG2_3classes
# Out:
#       molecule_chembl_id                           cleaned_canonical_smiles  \
# 0            CHEMBL39380  COC(=O)CC(O)CP(=O)([O-])CCc1c(Cl)cc(Cl)cc1OCc1...
# 1            CHEMBL39003  CC(C)(C)C(=O)OCOC(=O)CC(O)CP(=O)(CCc1c(Cl)cc(C...
# 2            CHEMBL39102  O=C(O)C[C@H](O)CP(=O)(O)CCc1c(Cl)cc(Cl)cc1OCc1...
# 3           CHEMBL162083                    O=S(=O)(CC#C/C=C\C#CCO)c1ccccc1
# 4           CHEMBL350898                COc1ccc(S(=O)(=O)CC#C/C=C\C#CCO)cc1
# ...                  ...                                                ...
# 18229      CHEMBL4649309  C=C[C@](C)(CO)n1cc(C[C@@H]2NC(=O)[C@H](C/C=C/C...
# 18230      CHEMBL4633849  C=C[C@](C)(CO)n1cc(C[C@@H]2NC(=O)[C@H](C/C=C/C...
# 18231      CHEMBL4637471  C=C[C@](C)(CO)n1cc(C[C@@H]2NC(=O)[C@H](C/C=C/C...
# 18232      CHEMBL4643250  C=C1CC[C@@H](C(C)C)[C@H]2/C=C(/C(=O)OC)CC/C=C(...
# 18233      CHEMBL1971943  Cc1c[nH]c2nccc(Oc3c(F)cc(Nc4cc(Cl)nc(N)n4)cc3F...
#
# ...

# %%
selection = ['cleaned_canonical_smiles', 'molecule_chembl_id']

# %%
tidy_target_HepG2_3classes_selection = tidy_target_HepG2_3classes[selection]
tidy_target_HepG2_3classes_selection.head()
# Out:
#                             cleaned_canonical_smiles molecule_chembl_id
# 0  COC(=O)CC(O)CP(=O)([O-])CCc1c(Cl)cc(Cl)cc1OCc1...        CHEMBL39380
# 1  CC(C)(C)C(=O)OCOC(=O)CC(O)CP(=O)(CCc1c(Cl)cc(C...        CHEMBL39003
# 2  O=C(O)C[C@H](O)CP(=O)(O)CCc1c(Cl)cc(Cl)cc1OCc1...        CHEMBL39102
# 3                    O=S(=O)(CC#C/C=C\C#CCO)c1ccccc1       CHEMBL162083
# 4                COc1ccc(S(=O)(=O)CC#C/C=C\C#CCO)cc1       CHEMBL350898

# %%
tidy_target_HepG2_3classes_selection.to_csv('./data/tidy_target_HepG2_3classes_selection.smi', sep='\t', index=False, header=False)

# %%
# !cat './data/tidy_target_HepG2_3classes_selection.smi' | head -5
# Out:
# COC(=O)CC(O)CP(=O)([O-])CCc1c(Cl)cc(Cl)cc1OCc1ccccc1	CHEMBL39380
# CC(C)(C)C(=O)OCOC(=O)CC(O)CP(=O)(CCc1c(Cl)cc(Cl)cc1OCc1ccccc1)OCOC(=O)C(C)(C)C	CHEMBL39003
# O=C(O)C[C@H](O)CP(=O)(O)CCc1c(Cl)cc(Cl)cc1OCc1ccccc1	CHEMBL39102
# O=S(=O)(CC#C/C=C\C#CCO)c1ccccc1	CHEMBL162083
# COc1ccc(S(=O)(=O)CC#C/C=C\C#CCO)cc1	CHEMBL350898
# cat: stdout: Broken pipe

# %%
# !cat './data/tidy_target_HepG2_3classes_selection.smi' | wc -l
# Out:
#    18234

# %% [markdown]
# ## Calculate fingerprint descriptors

# %% [markdown]
# ### Caluculate PaDEL descriptors

# %%
! cat padel.sh
# Out:
# java -Xms1G -Xmx1G -Djava.awt.headless=true -jar ./PaDEL-Descriptor/PaDEL-Descriptor.jar -removesalt -standardizenitro -fingerprints -descriptortypes ./PaDEL-Descriptor/PubchemFingerprinter.xml -dir ./ -file descriptors_output.csv

# %% [markdown]
# **Move `cleaned_strigolactone_targets_3classes_selection.smi` file to the same location as `padel.sh`**

# %%
# !mv './data/tidy_target_HepG2_3classes_selection.smi' './'

# %% [markdown]
# **Calculate descriptors**

# %%
# !bash padel.sh
# Out:
# Processing CHEMBL39380 in tidy_target_HepG2_3classes_selection.smi (1/18234).
# Processing CHEMBL350267 in tidy_target_HepG2_3classes_selection.smi (7/18234).
# Processing CHEMBL350898 in tidy_target_HepG2_3classes_selection.smi (5/18234).
# Processing CHEMBL349491 in tidy_target_HepG2_3classes_selection.smi (8/18234).
# Processing CHEMBL39102 in tidy_target_HepG2_3classes_selection.smi (3/18234).
# Processing CHEMBL39003 in tidy_target_HepG2_3classes_selection.smi (2/18234).
# Processing CHEMBL162083 in tidy_target_HepG2_3classes_selection.smi (4/18234).
# Processing CHEMBL161188 in tidy_target_HepG2_3classes_selection.smi (6/18234).
# Processing CHEMBL161187 in tidy_target_HepG2_3classes_selection.smi (10/18234). Average speed: 12.48 s/mol.
# Processing CHEMBL162252 in tidy_target_HepG2_3classes_selection.smi (9/18234). Average speed: 12.39 s/mol.
# Processing CHEMBL16120 in tidy_target_HepG2_3classes_selection.smi (11/18234). Average speed: 4.41 s/mol.
# ...

# %%
# !mv './descriptors_output.csv' './data/'
